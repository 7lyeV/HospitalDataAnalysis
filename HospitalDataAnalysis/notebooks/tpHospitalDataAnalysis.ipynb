# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\pc\HospitalDataAnalysis\data\patients.csv")

# %%
df.head()
# Out:
#    PatientID  Age Sex BloodPressure  Cholesterol     Diagnosis
# 0          1   45   M        120/80          200       Healthy
# 1          2   62   F        140/90          240  Hypertension
# 2          3   35   M        130/85          180       Healthy
# 3          4   58   F        150/95          260      Diabetes
# 4          5   41   M        125/82          220       Healthy

# %%
df.describe()
df['Sex'].value_counts()
# Out:
# Sex
# M    5
# F    5
# Name: count, dtype: int64

# %%
df['Diagnosis'].value_counts()
# Out:
# Diagnosis
# Healthy         4
# Hypertension    3
# Diabetes        3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["Age"], df['Cholesterol'], marker="o")
plt.xlabel("Age")
plt.ylabel("Cholesterol")
plt.title("Cholesterol vs Age")
plt.show()
